# %%
import pandas as pd
import requests
from config import api_key
import json

# %%
# to find list of republicans, this search will be the same, 
# except the party param will equal "Rep" instead of "Dem"

url="https://api.open.fec.gov/v1/candidates/"
params={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    
    "office":"S",
    "api_key":api_key,
    "party":"Dem"
}
data=requests.get(url=url,params=params).json()

# %%
candidate_page_1=pd.DataFrame(data["results"])
candidate_page_1.head()
# Out:
#   party incumbent_challenge_full  federal_funds_flag              name  \
# 0   DEM                Open seat               False    ADAMS, ELLIOTT
# 1   DEM               Challenger               False       AHLERS, DAN
# 2   DEM               Challenger               False  AUSBROOKS, JIMMY
# 3   DEM               Challenger               False         BAER, DAN
# 4   DEM               Challenger               False     BALLARD, JACK
#
#    active_through office office_full election_years district  \
# 0            2020      S      Senate         [2020]       00
# 1            2020      S      Senate         [2020]       00
# 2            2020      S      Senate         [2020]       00
# 3            2020      S      Senate         [2020]       00
# 4            2020      S      Senate         [2020]       00
#
#   incumbent_challenge  ...        party_full district_number        cycles  \
# 0                   O  ...  DEMOCRATIC PARTY               0  [2018, 2020]
# 1                   C  ...  DEMOCRATIC PARTY               0        [2020]
# 2                   C  ...  DEMOCRATIC PARTY               0        [2020]
# 3                   C  ...  DEMOCRATIC PARTY               0        [2020]
# 4                   C  ...  DEMOCRATIC PARTY               0        [2020]
#
#   election_districts      flags candidate_status  candidate_inactive  \
# 0               [00]  S0KS00190                N               False
# 1               [00]  S0SD00070                C               False
# 2               [00]  S0KY00313                N               False
# 3               [00]  S0CO00500                C               False
# 4               [00]  S0MT00116                C               False
#
#                    load_date inactive_election_years candidate_id
# 0  2019-01-08T21:04:16+00:00                    None    S0KS00190
# 1  2020-02-27T22:00:38+00:00                    None    S0SD00070
# 2  2019-06-10T21:08:12+00:00                    None    S0KY00313
# 3  2019-07-22T21:11:27+00:00                    None    S0CO00500
# 4  2019-10-17T21:13:50+00:00                    None    S0MT00116
#
# [5 rows x 25 columns]

# %%
# Here is the call for the second page. this is an exacy copy
# of the search above, except i added a "page" param, which
# is set to page 2. this will get results 21 - 40. 

url="https://api.open.fec.gov/v1/candidates/"
params_2={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":2
}
page_2=requests.get(url=url,params=params_2).json()

# %%
candidate_page_2=pd.DataFrame(page_2["results"])
candidate_page_2.head()
# Out:
#   office last_file_date                                cycles state district  \
# 0      S     2019-11-05                                [2020]    OK       00
# 1      S     2020-09-21                                [2020]    MT       00
# 2      S     2019-04-17                                [2020]    CO       00
# 3      S     2019-05-13                                [2020]    MT       00
# 4      S     2020-04-15  [2010, 2012, 2014, 2016, 2018, 2020]    DE       00
#
#   first_file_date                   name  district_number  has_raised_funds  \
# 0      2019-11-05          BROYLES, ABBY                0              True
# 1      2020-03-09         BULLOCK, STEVE                0              True
# 2      2019-04-17       BURNES, ELLEN DR                0              True
# 3      2019-05-13  COLLINS, WILMOT JAMES                0              True
# 4      2010-02-03  COONS, CHRISTOPHER A.                0              True
#
#    active_through  ... incumbent_challenge_full  candidate_id      flags  \
# 0            2020  ...               Challenger     S0OK00370  S0OK00370
# 1            2020  ...               Challenger     S0MT00173  S0MT00173
# 2            2020  ...               Challenger     S0CO00526  S0CO00526
# 3            2020  ...               Challenger     S0MT00090  S0MT00090
# 4            2020  ...                Incumbent     S0DE00092  S0DE00092
#
#   election_districts party candidate_status office_full incumbent_challenge  \
# 0               [00]   DEM                C      Senate                   C
# 1               [00]   DEM                C      Senate                   C
# 2               [00]   DEM                C      Senate                   C
# 3               [00]   DEM                C      Senate                   C
# 4       [00, 00, 00]   DEM                C      Senate                   I
#
#        election_years federal_funds_flag
# 0              [2020]              False
# 1              [2020]              False
# 2              [2020]              False
# 3              [2020]              False
# 4  [2010, 2014, 2020]              False
#
# [5 rows x 25 columns]

# %%
# page 3 search. 

url="https://api.open.fec.gov/v1/candidates/"
params_3={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":3
}
page_3=requests.get(url=url,params=params_3).json()

# %%
# page 3 df
candidate_page_3=pd.DataFrame(page_3["results"])
candidate_page_3.head()
# Out:
#        flags incumbent_challenge election_districts  candidate_inactive  \
# 0  S0ME00111                   C               [00]               False
# 1  S0IA00168                   C               [00]               False
# 2  S0IA00176                   C               [00]               False
# 3  S0KS00232                   O               [00]               False
# 4  S0NJ00233                   C               [00]               False
#
#   first_file_date                  load_date office last_file_date state  \
# 0      2019-06-24  2020-07-16T21:12:01+00:00      S     2020-07-15    ME
# 1      2019-05-31  2019-07-22T21:11:27+00:00      S     2019-05-31    IA
# 2      2019-06-03  2020-07-14T21:11:34+00:00      S     2020-07-14    IA
# 3      2019-07-01  2019-10-25T21:28:14+00:00      S     2019-07-01    KS
# 4      2020-01-02  2020-04-17T21:33:17+00:00      S     2020-01-02    NJ
#
#   candidate_id  ... candidate_status                 name  \
# 0    S0ME00111  ...                C         GIDEON, SARA
# 1    S0IA00168  ...                C     GRAHAM, KIMBERLY
# 2    S0IA00176  ...                C  GREENFIELD, THERESA
# 3    S0KS00232  ...                C       GRISSOM, BARRY
# 4    S0NJ00233  ...                C   HAMM, LAWRENCE MR.
#
#    incumbent_challenge_full active_through  federal_funds_flag office_full  \
# 0                Challenger           2020               False      Senate
# 1                Challenger           2020               False      Senate
# 2                Challenger           2020               False      Senate
# 3                 Open seat           2020               False      Senate
# 4                Challenger           2020               False      Senate
#
#   election_years last_f2_date        party_full  party
# 0         [2020]   2020-07-15  DEMOCRATIC PARTY    DEM
# 1         [2020]   2019-05-31  DEMOCRATIC PARTY    DEM
# 2         [2020]   2020-07-14  DEMOCRATIC PARTY    DEM
# 3         [2020]   2019-07-01  DEMOCRATIC PARTY    DEM
# 4         [2020]   2020-01-02  DEMOCRATIC PARTY    DEM
#
# [5 rows x 25 columns]

# %%
# page 4

url="https://api.open.fec.gov/v1/candidates/"
params_4={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":4
}
page_4=requests.get(url=url,params=params_4).json()

# %%
candidate_page_4=pd.DataFrame(page_4["results"])
candidate_page_4.head()
# Out:
#    district_number candidate_status last_f2_date  active_through district  \
# 0                0                N   2019-09-03            2020       00
# 1                0                C   2020-02-12            2020       00
# 2                0                C   2020-08-28            2020       00
# 3                0                C   2019-09-26            2020       00
# 4                0                C   2019-08-26            2020       00
#
#   office_full                          cycles inactive_election_years  \
# 0      Senate                          [2020]                    None
# 1      Senate                          [2020]                    None
# 2      Senate                          [2020]                    None
# 3      Senate  [2012, 2014, 2016, 2018, 2020]                    None
# 4      Senate                          [2020]                    None
#
#          party_full party  ...                  load_date  federal_funds_flag  \
# 0  DEMOCRATIC PARTY   DEM  ...  2019-09-11T21:16:35+00:00               False
# 1  DEMOCRATIC PARTY   DEM  ...  2020-04-17T21:33:17+00:00               False
# 2  DEMOCRATIC PARTY   DEM  ...  2020-08-30T01:02:27+00:00               False
# 3  DEMOCRATIC PARTY   DEM  ...  2019-09-26T21:09:13+00:00               False
# 4  DEMOCRATIC PARTY   DEM  ...  2019-09-30T21:06:22+00:00               False
#
#                    election_years first_file_date state      flags  office  \
# 0                          [2020]      2019-09-03    IL  S0IL00576       S
# 1                          [2020]      2020-02-12    ID  S0ID00180       S
# 2                          [2020]      2019-02-12    AZ  S0AZ00350       S
# 3  [2012, 2014, 2016, 2018, 2020]      2012-02-15    MA  H2MA04073       S
# 4                          [2020]      2019-08-26    MA  S0MA00208       S
#
#   incumbent_challenge    election_districts                    name
# 0                   C                  [00]  JORDAN LAWLOR, MARILYN
# 1                   C                  [00]        JORDAN, PAULETTE
# 2                   C                  [00]             KELLY, MARK
# 3                   I  [04, 04, 04, 04, 00]   KENNEDY, JOSEPH P III
# 4                   C                  [00]   KENNEDY, JOSEPH P III
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_5={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":5
}
page_5=requests.get(url=url,params=params_5).json()

# %%
candidate_page_5=pd.DataFrame(page_5["results"])
candidate_page_5.head()
# Out:
#   office last_file_date                                      cycles state  \
# 0      S     2019-06-18                                      [2020]    NC
# 1      S     2019-10-08  [1984, 1986, 1988, 2014, 2016, 2018, 2020]    MA
# 2      S     2020-02-03        [2008, 2012, 2014, 2016, 2018, 2020]    NE
# 3      S     2019-05-15                                      [2020]    IA
# 4      S     2020-05-17                                      [2020]    GA
#
#   district first_file_date                    name  district_number  \
# 0       00      2019-06-18         MANSFIELD, ERIC                0
# 1       00      1984-01-30  MARKEY, EDWARD J. SEN.                0
# 2       00      2011-09-22           MARVIN, LARRY                0
# 3       00      2019-05-15          MAURO, EDDIE J                0
# 4       00      2020-05-10       MCCRACKEN, TRICIA                0
#
#    has_raised_funds  active_through  ... incumbent_challenge_full  \
# 0              True            2020  ...               Challenger
# 1              True            2020  ...                Incumbent
# 2              True            2020  ...               Challenger
# 3              True            2020  ...               Challenger
# 4              True            2020  ...               Challenger
#
#    candidate_id      flags    election_districts party candidate_status  \
# 0     S0NC00327  S0NC00327                  [00]   DEM                C
# 1     S4MA00028  S4MA00028          [00, 00, 00]   DEM                C
# 2     S8NE00141  S8NE00141  [00, 00, 00, 00, 00]   DEM                C
# 3     S0IA00150  S0IA00150                  [00]   DEM                C
# 4     S0GA00666  S0GA00666                  [00]   DEM                C
#
#   office_full incumbent_challenge                  election_years  \
# 0      Senate                   C                          [2020]
# 1      Senate                   I              [1984, 2014, 2020]
# 2      Senate                   C  [2008, 2012, 2014, 2018, 2020]
# 3      Senate                   C                          [2020]
# 4      Senate                   C                          [2020]
#
#   federal_funds_flag
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_6={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":6
}
page_6=requests.get(url=url,params=params_6).json()

# %%
candidate_page_6=pd.DataFrame(page_6["results"])
candidate_page_6.head()
# Out:
#   office last_file_date                                cycles state district  \
# 0      S     2019-08-26                                [2020]    GA       00
# 1      S     2020-02-10                                [2020]    WV       00
# 2      S     2019-08-26                                [2020]    OK       00
# 3      S     2019-03-12  [2010, 2012, 2014, 2016, 2018, 2020]    CO       00
# 4      S     2019-09-16                                [2020]    KY       00
#
#   first_file_date                 name  district_number  has_raised_funds  \
# 0      2019-07-15   RIGGS AMICO, SARAH                0              True
# 1      2020-02-10  ROBB, RICHARD ALLEN                0              True
# 2      2019-08-26        ROGERS, BEVON                0              True
# 3      2009-09-05     ROMANOFF, ANDREW                0              True
# 4      2019-09-16     ROTHMULLER, ERIC                0              True
#
#    active_through  ... incumbent_challenge_full  candidate_id      flags  \
# 0            2020  ...               Challenger     S0GA00401  S0GA00401
# 1            2020  ...               Challenger     S0WV00256  S0WV00256
# 2            2020  ...               Challenger     S0OK00354  S0OK00354
# 3            2020  ...               Challenger     S0CO00286  S0CO00286
# 4            2020  ...               Challenger     S0KY00388  S0KY00388
#
#   election_districts party candidate_status office_full incumbent_challenge  \
# 0               [00]   DEM                C      Senate                   C
# 1               [00]   DEM                C      Senate                   C
# 2               [00]   DEM                N      Senate                   C
# 3           [00, 00]   DEM                C      Senate                   C
# 4               [00]   DEM                N      Senate                   C
#
#   election_years federal_funds_flag
# 0         [2020]              False
# 1         [2020]              False
# 2         [2020]              False
# 3   [2010, 2020]              False
# 4         [2020]              False
#
# [5 rows x 25 columns]

# %%
dfs_to_concat = [candidate_page_1, candidate_page_2, candidate_page_3, candidate_page_4, candidate_page_5,candidate_page_6]

# %%
dem_candidates=pd.concat(dfs_to_concat)

# %%
dem_candidates=dem_candidates[["name", "candidate_id", "state", "party", "incumbent_challenge_full", "office_full", "cycles", "election_years", "party", "candidate_status"]]

# %%
dem_candidates.reset_index()
# Out:
#      index                        name candidate_id state party  \
# 0        0              ADAMS, ELLIOTT    S0KS00190    KS   DEM
# 1        1                 AHLERS, DAN    S0SD00070    SD   DEM
# 2        2            AUSBROOKS, JIMMY    S0KY00313    KY   DEM
# 3        3                   BAER, DAN    S0CO00500    CO   DEM
# 4        4               BALLARD, JACK    S0MT00116    MT   DEM
# ..     ...                         ...          ...   ...   ...
# 115     15              SWENSON, STEVE    S0NC00368    NC   DEM
# 116     16           TARVER, EDWARD J.    S0GA00583    GA   DEM
# 117     17               TERRY, EDWARD    S0GA00419    GA   DEM
# 118     18        TILLMAN, ROBERT LEON    S0KS00265    KS   DEM
# 119     19  TINUBU, GLORIA BROMELL DR.    S0SC00305    SC   DEM
#
#     incumbent_challenge_full office_full        cycles election_years party  \
# 0                  Open seat      Senate  [2018, 2020]         [2020]   DEM
# 1                 Challenger      Senate        [2020]         [2020]   DEM
# 2                 Challenger      Senate        [2020]         [2020]   DEM
# 3                 Challenger      Senate        [2020]         [2020]   DEM
# 4                 Challenger      Senate        [2020]         [2020]   DEM
# ..                       ...         ...           ...            ...   ...
# 115               Challenger      Senate        [2020]         [2020]   DEM
# 116               Challenger      Senate        [2020]         [2020]   DEM
# 117               Challenger      Senate        [2020]         [2020]   DEM
# 118                Open seat      Senate        [2020]         [2020]   DEM
# 119               Challenger      Senate        [2020]         [2020]   DEM
#
#     candidate_status
# 0                  N
# 1                  C
# 2                  N
# 3                  C
# 4                  C
# ..               ...
# 115                N
# 116                C
# 117                C
# 118                N
# 119                C
#
# [120 rows x 11 columns]

# %%
dem_candidates.to_csv("2020_dem_candidate.csv")
