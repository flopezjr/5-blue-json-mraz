# %%
import pandas as pd
import requests
from config import api_key
import json

# %%
url="https://api.open.fec.gov/v1/candidates/"
params={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Rep"
}
data=requests.get(url=url,params=params).json()

# %%
candidate_page_1=pd.DataFrame(data["results"])
candidate_page_1.head()
# Out:
#   office last_file_date                                             cycles  \
# 0      S     2019-04-11                                             [2020]
# 1      S     2019-07-06                                             [2020]
# 2      S     2014-12-16  [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...
# 3      S     2019-05-17                                       [2018, 2020]
# 4      S     2019-06-28                                             [2020]
#
#   state district first_file_date                 name  district_number  \
# 0    AL       00      2019-04-11     ADAIR, STANLEY E                0
# 1    VA       00      2019-07-06    ADKINS, GARY GENE                0
# 2    TN       00      2002-04-03     ALEXANDER, LAMAR                0
# 3    MA       00      2017-03-17  AYYADURAI, SHIVA DR                0
# 4    VA       00      2019-06-28      BALDWIN, ALISSA                0
#
#    has_raised_funds  active_through  ... incumbent_challenge_full  \
# 0              True            2020  ...               Challenger
# 1              True            2020  ...               Challenger
# 2              True            2020  ...                Incumbent
# 3              True            2020  ...               Challenger
# 4              True            2020  ...               Challenger
#
#    candidate_id      flags election_districts party candidate_status  \
# 0     S0AL00248  S0AL00248               [00]   REP                C
# 1     S0VA00096  S0VA00096               [00]   REP                C
# 2     S2TN00058  S2TN00058   [00, 00, 00, 00]   REP                C
# 3     S8MA00268  S8MA00268           [00, 00]   REP                C
# 4     S0VA00070  S0VA00070               [00]   REP                C
#
#   office_full incumbent_challenge            election_years federal_funds_flag
# 0      Senate                   C                    [2020]              False
# 1      Senate                   C                    [2020]              False
# 2      Senate                   I  [2002, 2008, 2014, 2020]              False
# 3      Senate                   C              [2018, 2020]              False
# 4      Senate                   C                    [2020]              False
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_2={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Rep",
    "page":2
}
page_2=requests.get(url=url,params=params_2).json()

# %%
candidate_page_2=pd.DataFrame(page_2["results"])
candidate_page_2.head()
# Out:
#        flags incumbent_challenge                election_districts  \
# 0  S8MS00055                   I  [00, 00, 00, 00, 00, 00, 00, 00]
# 1  S0GA00567                   C                              [00]
# 2  S6ME00159                   I              [00, 00, 00, 00, 00]
# 3  S0TN00243                   O                              [00]
# 4  S2TX00106                   I                  [00, 00, 00, 00]
#
#    candidate_inactive first_file_date                  load_date office  \
# 0                True      1978-05-19  2019-03-27T21:06:35+00:00      S
# 1               False      2020-01-30  2020-04-16T21:12:37+00:00      S
# 2               False      1996-02-22  2019-10-09T21:11:04+00:00      S
# 3               False      2020-02-27  2020-05-05T21:11:57+00:00      S
# 4               False      2001-09-14  2020-09-04T01:07:14+00:00      S
#
#   last_file_date state candidate_id  ... candidate_status  \
# 0     2014-11-26    MS    S8MS00055  ...                C
# 1     2020-01-30    GA    S0GA00567  ...                C
# 2     2019-10-09    ME    S6ME00159  ...                C
# 3     2020-02-27    TN    S0TN00243  ...                C
# 4     2020-09-03    TX    S2TX00106  ...                C
#
#                      name  incumbent_challenge_full active_through  \
# 0           COCHRAN, THAD                 Incumbent           2020
# 1  COLLINS, DOUGLAS ALLEN                Challenger           2020
# 2       COLLINS, SUSAN M.                 Incumbent           2020
# 3          COPE, ROY DALE                 Open seat           2020
# 4        CORNYN, JOHN SEN                 Incumbent           2020
#
#    federal_funds_flag office_full  \
# 0               False      Senate
# 1               False      Senate
# 2               False      Senate
# 3               False      Senate
# 4               False      Senate
#
#                                      election_years last_f2_date  \
# 0  [1978, 1984, 1990, 1996, 2002, 2008, 2014, 2020]   2014-11-26
# 1                                            [2020]   2020-01-30
# 2                    [1996, 2002, 2008, 2014, 2020]   2019-10-09
# 3                                            [2020]   2020-02-27
# 4                          [2002, 2008, 2014, 2020]   2020-09-03
#
#          party_full  party
# 0  REPUBLICAN PARTY    REP
# 1  REPUBLICAN PARTY    REP
# 2  REPUBLICAN PARTY    REP
# 3  REPUBLICAN PARTY    REP
# 4  REPUBLICAN PARTY    REP
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_3={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Rep",
    "page":3
}
page_3=requests.get(url=url,params=params_3).json()

# %%
candidate_page_3=pd.DataFrame(page_3["results"])
candidate_page_3.head()
# Out:
#   incumbent_challenge  active_through  federal_funds_flag  \
# 0                   I            2020               False
# 1                   C            2020               False
# 2                   O            2020               False
# 3                   O            2020               False
# 4                   O            2020               False
#
#                                               cycles  \
# 0  [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...
# 1                                             [2020]
# 2                                             [2020]
# 3                                             [2020]
# 4                                             [2020]
#
#                    load_date office_full candidate_id  candidate_inactive  \
# 0  2020-09-06T01:02:19+00:00      Senate    S0SC00149               False
# 1  2020-05-05T21:11:57+00:00      Senate    S0GA00658               False
# 2  2020-09-15T22:27:16+00:00      Senate    S0TN00169               False
# 3  2020-05-05T21:11:57+00:00      Senate    S0KS00349               False
# 4  2020-07-17T21:08:13+00:00      Senate    S0TN00276               False
#
#   last_f2_date inactive_election_years  ...        party_full  \
# 0   2020-09-05                    None  ...  REPUBLICAN PARTY
# 1   2020-04-21                    None  ...  REPUBLICAN PARTY
# 2   2020-09-15                    None  ...  REPUBLICAN PARTY
# 3   2020-03-30                    None  ...  REPUBLICAN PARTY
# 4   2020-03-30                    None  ...  REPUBLICAN PARTY
#
#   election_districts candidate_status            election_years state office  \
# 0   [00, 00, 00, 00]                C  [2002, 2008, 2014, 2020]    SC      S
# 1               [00]                C                    [2020]    GA      S
# 2               [00]                C                    [2020]    TN      S
# 3               [00]                C                    [2020]    KS      S
# 4               [00]                C                    [2020]    TN      S
#
#   incumbent_challenge_full      flags district_number first_file_date
# 0                Incumbent  S0SC00149               0      2001-01-31
# 1               Challenger  S0GA00658               0      2020-04-21
# 2                Open seat  S0TN00169               0      2019-09-09
# 3                Open seat  S0KS00349               0      2020-03-30
# 4                Open seat  S0TN00276               0      2020-03-30
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_4={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Rep",
    "page":4
}
page_4=requests.get(url=url,params=params_4).json()

# %%
candidate_page_4=pd.DataFrame(page_4["results"])
candidate_page_4.head()
# Out:
#                    load_date incumbent_challenge last_f2_date  \
# 0  2020-05-04T21:13:47+00:00                   C   2020-05-04
# 1  2019-07-23T21:24:02+00:00                   O   2019-07-03
# 2  2020-09-04T01:07:14+00:00                   I   2020-09-03
# 3  2020-03-17T21:18:19+00:00                   O   2020-03-16
# 4  2019-08-02T21:23:47+00:00                   C   2019-05-28
#
#      election_districts  active_through district last_file_date state  \
# 0                  [00]            2020       00     2020-05-04    MN
# 1                  [00]            2020       00     2019-07-03    KS
# 2                  [00]            2020       00     2020-09-03    GA
# 3                  [00]            2020       00     2020-03-16    WY
# 4  [00, 00, 00, 00, 00]            2020       00     2019-05-28    IL
#
#   incumbent_challenge_full                        name  ...  \
# 0               Challenger                LEWIS, JASON  ...
# 1                Open seat       LINDSTROM, DAVID ALAN  ...
# 2                Incumbent             LOEFFLER, KELLY  ...
# 3                Open seat  LUMMIS, CYNTHIA MARIE MRS.  ...
# 4               Challenger            MARSHALL, ROBERT  ...
#
#   candidate_inactive  candidate_status office_full        party_full  \
# 0              False                 C      Senate  REPUBLICAN PARTY
# 1              False                 C      Senate  REPUBLICAN PARTY
# 2              False                 C      Senate  REPUBLICAN PARTY
# 3              False                 C      Senate  REPUBLICAN PARTY
# 4              False                 C      Senate  REPUBLICAN PARTY
#
#   inactive_election_years                  election_years first_file_date  \
# 0                    None                          [2020]      2019-08-23
# 1                    None                          [2020]      2019-07-03
# 2                    None                          [2020]      2019-12-04
# 3                    None                          [2020]      2019-06-20
# 4                    None  [1996, 1998, 2010, 2016, 2020]      1995-08-07
#
#        flags candidate_id has_raised_funds
# 0  S0MN00328    S0MN00328             True
# 1  S0KS00240    S0KS00240             True
# 2  S0GA00526    S0GA00526             True
# 3  S0WY00137    S0WY00137             True
# 4  S6IL00185    S6IL00185             True
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_5={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Rep",
    "page":5
}
page_5=requests.get(url=url,params=params_5).json()

# %%
candidate_page_5=pd.DataFrame(page_5["results"])
candidate_page_5.head()
# Out:
#   office election_years                  load_date last_f2_date  cycles  \
# 0      S         [2020]  2019-07-22T21:11:27+00:00   2019-06-27  [2020]
# 1      S         [2020]  2019-07-22T21:11:27+00:00   2019-05-16  [2020]
# 2      S         [2020]  2020-05-05T21:11:57+00:00   2020-03-24  [2020]
# 3      S         [2020]  2020-08-21T01:04:24+00:00   2020-05-29  [2020]
# 4      S         [2020]  2019-10-25T21:28:14+00:00   2019-07-03  [2020]
#
#                         name  district_number  candidate_inactive  \
# 0         MOORE, ROY STEWART                0               False
# 1     MORGAN, CLINTON WESLEY                0               False
# 2              MORRELL, KENT                0               False
# 3             MURPHY, DUSTIN                0               False
# 4  O'BRIEN, WILLIAM LAWRENCE                0               False
#
#   first_file_date      flags  ...        party_full candidate_status  \
# 0      2019-06-27  S0AL00297  ...  REPUBLICAN PARTY                C
# 1      2019-05-16  S0KY00297  ...  REPUBLICAN PARTY                C
# 2      2020-03-24  S0TN00250  ...  REPUBLICAN PARTY                N
# 3      2020-05-29  S0LA00352  ...  REPUBLICAN PARTY                N
# 4      2019-07-03  S0NH00318  ...  REPUBLICAN PARTY                C
#
#   active_through  last_file_date party inactive_election_years  \
# 0           2020      2019-06-27   REP                    None
# 1           2020      2019-05-16   REP                    None
# 2           2020      2020-03-24   REP                    None
# 3           2020      2020-05-29   REP                    None
# 4           2020      2019-07-03   REP                    None
#
#   has_raised_funds  state incumbent_challenge election_districts
# 0             True     AL                   C               [00]
# 1             True     KY                   C               [00]
# 2             True     TN                   O               [00]
# 3             True     LA                   C               [00]
# 4             True     NH                   C               [00]
#
# [5 rows x 25 columns]

# %%
concat_reps = [candidate_page_1, candidate_page_2, candidate_page_3, candidate_page_4, candidate_page_5]

# %%
# new df created by concat'ing the list above
rep_candidates=pd.concat(concat_reps)

# %%
rep_candidates.reset_index()
# Out:
#     index office last_file_date  \
# 0       0      S     2019-04-11
# 1       1      S     2019-07-06
# 2       2      S     2014-12-16
# 3       3      S     2019-05-17
# 4       4      S     2019-06-28
# ..    ...    ...            ...
# 95     15      S     2014-11-19
# 96     16      S     2019-11-01
# 97     17      S     2020-09-09
# 98     18      S     2019-12-27
# 99     19      S     2019-12-31
#
#                                                cycles state district  \
# 0                                              [2020]    AL       00
# 1                                              [2020]    VA       00
# 2   [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...    TN       00
# 3                                        [2018, 2020]    MA       00
# 4                                              [2020]    VA       00
# ..                                                ...   ...      ...
# 95  [1996, 1998, 2000, 2002, 2004, 2006, 2008, 201...    KS       00
# 96                                             [2020]    OR       00
# 97                                             [2020]    NM       00
# 98                     [2012, 2014, 2016, 2018, 2020]    SD       00
# 99                                             [2020]    NM       00
#
#    first_file_date                         name  district_number  \
# 0       2019-04-11             ADAIR, STANLEY E                0
# 1       2019-07-06            ADKINS, GARY GENE                0
# 2       2002-04-03             ALEXANDER, LAMAR                0
# 3       2017-03-17          AYYADURAI, SHIVA DR                0
# 4       2019-06-28              BALDWIN, ALISSA                0
# ..             ...                          ...              ...
# 95      1996-01-19                 ROBERTS, PAT                0
# 96      2019-11-01  ROMERO, PAUL JOSEPH MR. JR.                0
# 97      2020-01-07           RONCHETTI, MARK V.                0
# 98      2012-10-10                 ROUNDS, MIKE                0
# 99      2019-12-31             SANCHEZ, LOUIE J                0
#
#     has_raised_funds  ...  incumbent_challenge_full candidate_id      flags  \
# 0               True  ...                Challenger    S0AL00248  S0AL00248
# 1               True  ...                Challenger    S0VA00096  S0VA00096
# 2               True  ...                 Incumbent    S2TN00058  S2TN00058
# 3               True  ...                Challenger    S8MA00268  S8MA00268
# 4               True  ...                Challenger    S0VA00070  S0VA00070
# ..               ...  ...                       ...          ...        ...
# 95              True  ...                 Incumbent    S6KS00080  S6KS00080
# 96              True  ...                Challenger    S0OR00337  S0OR00337
# 97              True  ...                 Open seat    S0NM00124  S0NM00124
# 98              True  ...                 Incumbent    S4SD00049  S4SD00049
# 99              True  ...                 Open seat    S0NM00116  S0NM00116
#
#       election_districts party candidate_status office_full  \
# 0                   [00]   REP                C      Senate
# 1                   [00]   REP                C      Senate
# 2       [00, 00, 00, 00]   REP                C      Senate
# 3               [00, 00]   REP                C      Senate
# 4                   [00]   REP                C      Senate
# ..                   ...   ...              ...         ...
# 95  [00, 00, 00, 00, 00]   REP                C      Senate
# 96                  [00]   REP                C      Senate
# 97                  [00]   REP                C      Senate
# 98              [00, 00]   REP                C      Senate
# 99                  [00]   REP                C      Senate
#
#    incumbent_challenge                  election_years federal_funds_flag
# 0                    C                          [2020]              False
# 1                    C                          [2020]              False
# 2                    I        [2002, 2008, 2014, 2020]              False
# 3                    C                    [2018, 2020]              False
# 4                    C                          [2020]              False
# ..                 ...                             ...                ...
# 95                   I  [1996, 2002, 2008, 2014, 2020]              False
# 96                   C                          [2020]              False
# 97                   O                          [2020]              False
# 98                   I                    [2014, 2020]              False
# 99                   O                          [2020]              False
#
# [100 rows x 26 columns]

# %%
rep_candidates.to_csv("2020_rep_candidate.csv")

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_6={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2020,
    "office":"S",
    "api_key":api_key,
    "party":"Rep",
    "page":6
}
page_6=requests.get(url=url,params=params_6).json()

# %%
candidate_page_6=pd.DataFrame(page_6["results"])
candidate_page_6.head()
# Out:
#   party incumbent_challenge_full  federal_funds_flag                   name  \
# 0   REP                Incumbent               False      SASSE, BENJAMIN E
# 1   REP               Challenger               False      SERBIN, JOHN PAUL
# 2   REP               Challenger               False  SESSIONS, JEFFERSON B
# 3   REP                Open seat               False       SETHI, DR. MANNY
# 4   REP                Open seat               False        SHORT, ROBERT G
#
#    active_through office office_full            election_years district  \
# 0            2020      S      Senate              [2014, 2020]       00
# 1            2020      S      Senate                    [2020]       00
# 2            2020      S      Senate  [2002, 2008, 2014, 2020]       00
# 3            2020      S      Senate                    [2020]       00
# 4            2020      S      Senate                    [2020]       00
#
#   incumbent_challenge  ...        party_full district_number  \
# 0                   I  ...  REPUBLICAN PARTY               0
# 1                   C  ...  REPUBLICAN PARTY               0
# 2                   C  ...  REPUBLICAN PARTY               0
# 3                   O  ...  REPUBLICAN PARTY               0
# 4                   O  ...  REPUBLICAN PARTY               0
#
#                                               cycles election_districts  \
# 0                           [2014, 2016, 2018, 2020]           [00, 00]
# 1                                             [2020]               [00]
# 2  [1996, 1998, 2000, 2002, 2004, 2006, 2008, 201...   [00, 00, 00, 00]
# 3                                             [2020]               [00]
# 4                                             [2020]               [00]
#
#        flags candidate_status  candidate_inactive                  load_date  \
# 0  S4NE00090                C               False  2019-03-27T21:06:35+00:00
# 1  S0AL00271                N               False  2019-06-14T21:08:39+00:00
# 2  S6AL00195                C               False  2020-01-03T21:09:36+00:00
# 3  S0TN00144                C               False  2019-07-25T21:14:37+00:00
# 4  S0WY00160                C               False  2020-04-08T21:16:25+00:00
#
#   inactive_election_years candidate_id
# 0                    None    S4NE00090
# 1                    None    S0AL00271
# 2                    None    S6AL00195
# 3                    None    S0TN00144
# 4                    None    S0WY00160
#
# [5 rows x 25 columns]

# %%
concat_reps = [candidate_page_1, candidate_page_2, candidate_page_3, candidate_page_4, candidate_page_5, candidate_page_6]

# %%
rep_candidates=pd.concat(concat_reps)
# rep_candidates.to_csv("2020_rep_candidate.csv")

# %%
rep_candidates.shape
# Out:
# (120, 25)

# %%
rep_candidates=rep_candidates[["name", "candidate_id", "state", "party", "incumbent_challenge_full", "office_full", "cycles", "election_years", "party", "candidate_status"]]

# %%
rep_candidates.head(0)
# Out:
# Empty DataFrame
# Columns: [name, candidate_id, state, party, incumbent_challenge_full, office_full, cycles, election_years, party, candidate_status]
# Index: []

# %%
rep_candidates.to_csv("2020_rep_candidate.csv")
