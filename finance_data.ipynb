# %%
import pandas as pd
import requests
from config import api_key
import json

# %%
dem_candidate_df=pd.read_csv("dem_candidate.csv")

# %%
url="https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/"

# %%
dem_candidate_df.head()
# Out:
#    Unnamed: 0                 name candidate_id state party  \
# 0           0       ABBOUD, DEEDRA    S8AZ00122    AZ   DEM
# 1           1  ADAMS, ANN MARIE DR    S8CT00105    CT   DEM
# 2           2       BALDWIN, TAMMY    S2WI00219    WI   DEM
# 3           3   BARIA, DAVID WAYNE    S8MS00253    MS   DEM
# 4           4        BARTEE, TOBEY    S8MS00295    MS   DEM
#
#   incumbent_challenge_full office_full                          cycles  \
# 0                Open seat      Senate                    [2018, 2020]
# 1               Challenger      Senate                          [2018]
# 2                Incumbent      Senate  [2012, 2014, 2016, 2018, 2020]
# 3                Open seat      Senate                    [2018, 2020]
# 4               Challenger      Senate                    [2018, 2020]
#
#        election_years party.1 candidate_status
# 0              [2018]     DEM                P
# 1              [2018]     DEM                N
# 2  [2012, 2018, 2024]     DEM                F
# 3              [2018]     DEM                P
# 4        [2018, 2020]     DEM                N

# %%
can_id=dem_candidate_df.candidate_id
can_id.to_list()
# Out:
# ['S8AZ00122',
#  'S8CT00105',
#  'S2WI00219',
#  'S8MS00253',
#  'S8MS00295',
#  'S8AZ00171',
#  'S8MS00220',
#  'S8AL00407',
#  'S8TN00386',
#  'S6OH00163',
#  'S8WA00194',
#  'S6MD03177',
#  'S8DE00079',
#  'S6PA00217',
#  'S8NV00131',
#  'S2TN00082',
#  'S8CA00408',
#  'S2IN00091',
#  'S6IL00292',
#  'S8MO00186',
#  'S8MS00287',
#  'S0CA00199',
#  'S8AL00357',
#  'S0NY00410',
#  'S8AL00373',
#  'S8CA00358',
#  'S8DE00137',
#  'S8CA00416',
#  'S2NM00088',
#  'S2ND00099',
#  'S8CA00317',
#  'S2HI00106',
#  'S8NJ00475',
#  'S8NJ00491',
#  'S8NE00216',
#  'S8MD00286',
#  'S0AL00156',
#  'S2VA00142',
#  'H2MA04073',
#  'S8AL00365',
#  'S8TX00376',
#  'S8MN00602',
#  'S8FL00240',
#  'S8TN00311',
#  'S6NV00234',
#  'S0WV00090',
#  'S8MD00260',
#  'S8NE00141',
#  'S6MO00305',
#  'S6NJ00289',
#  'S8AZ00155',
#  'S2CT00132',
#  'S8FL00166',
#  'S0NY00402',
#  'S8TX00285',
#  'S6CA00790',
#  'S8NE00182',
#  'S8ME00155',
#  'S8WA00228',
#  'S8NV00156',
#  'S2AZ00265',
#  'S8AZ00148',
#  'S8NV00149',
#  'S8MS00311',
#  'S8MD00252',
#  'S8MS00303',
#  'S8MS00246',
#  'S8AZ00197',
#  'S8UT00135',
#  'S8MN00578',
#  'S8MI00281',
#  'S6CA00873',
#  'S8MT00267',
#  'S8NE00224',
#  'S8WV00119',
#  'S6MT00162',
#  'S8WY00189',
#  'S8UT00150',
#  'S2MA00170',
#  'S6RI00221',
#  'S8UT00143']

# %%
def extract_data(results):
    return {
    "candidate_id":results["candidate_id"],
    "state": results["state_full"],
    "donation_count": results["count"],
    "total_raised": results["total"],
    "cycle": results["cycle"]
    }

# %%
dem_finance = []

for e in can_id:

    data = requests.get(url=url, params={
        "election_full": False,
        "sort_hide_null": False,
        "cycle": 2018,
        "api_key": api_key,
        "sort_nulls_last": False,
        "sort_null_only": False,
        "page": 1,
        "per_page":  20,
        "candidate_id": e

    }).json()
    
    dem_finances = extract_data(results)
    
    dem_finance.append(dem_finances)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-262507280bd4> in <module>
#      16     }).json()
#      17
# ---> 18     dem_finances = extract_data(results)
#      19
#      20     dem_finance.append(dem_finances)
#
# <ipython-input-51-9bd99611585a> in extract_data(results)
#       1 def extract_data(results):
#       2     return {
# ----> 3     "candidate_id":results["candidate_id"],
#       4     "state": results["state_full"],
#       5     "donation_count": results["count"],
#
# KeyError: 'candidate_id'

# %%
dem_finance
# Out:
# [{'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'},
#  {'candidate_id': 'S8UT00143'}]

# %%
results
# Out:
# {'api_version': '1.0',
#  'results': [{'candidate_id': 'S8MN00578',
#    'state': 'AK',
#    'count': 25,
#    'state_full': 'Alaska',
#    'total': 3310.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'AL',
#    'count': 12,
#    'state_full': 'Alabama',
#    'total': 2568.33,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'AR',
#    'count': 24,
#    'state_full': 'Arkansas',
#    'total': 3935.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'AZ',
#    'count': 59,
#    'state_full': 'Arizona',
#    'total': 13760.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'CA',
#    'count': 1207,
#    'state_full': 'California',
#    'total': 575113.08,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'CO',
#    'count': 137,
#    'state_full': 'Colorado',
#    'total': 60253.33,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'CT',
#    'count': 116,
#    'state_full': 'Connecticut',
#    'total': 17722.9,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'DC',
#    'count': 204,
#    'state_full': 'District Of Columbia',
#    'total': 176393.69,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'DE',
#    'count': 12,
#    'state_full': 'Delaware',
#    'total': 4174.98,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'FL',
#    'count': 259,
#    'state_full': 'Florida',
#    'total': 71104.07,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'GA',
#    'count': 77,
#    'state_full': 'Georgia',
#    'total': 21895.83,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'HI',
#    'count': 18,
#    'state_full': 'Hawaii',
#    'total': 4021.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'IA',
#    'count': 51,
#    'state_full': 'Iowa',
#    'total': 10670.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'ID',
#    'count': 9,
#    'state_full': 'Idaho',
#    'total': 1202.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'IL',
#    'count': 309,
#    'state_full': 'Illinois',
#    'total': 116266.6,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'IN',
#    'count': 61,
#    'state_full': 'Indiana',
#    'total': 16897.02,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'KS',
#    'count': 39,
#    'state_full': 'Kansas',
#    'total': 2850.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'KY',
#    'count': 39,
#    'state_full': 'Kentucky',
#    'total': 7151.33,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'LA',
#    'count': 21,
#    'state_full': 'Louisiana',
#    'total': 3391.0,
#    'cycle': 2018},
#   {'candidate_id': 'S8MN00578',
#    'state': 'MA',
#    'count': 632,
#    'state_full': 'Massachusetts',
#    'total': 310585.06,
#    'cycle': 2018}],
#  'pagination': {'per_page': 20, 'pages': 3, 'page': 1, 'count': 52}}

# %%
test=requests.get(url="https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?election_full=false&sort_hide_null=false&cycle=2018&api_key=gBPd8MAQBD1GtBebZr9BuUXeF8Ahv9rMLlDk3CV7&sort_nulls_last=false&sort_null_only=false&page=1&per_page=20&candidate_id=S8NV00149")

# %%
test.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 11, 'pages': 1, 'per_page': 20, 'page': 1},
#  'results': [{'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 1,
#    'total': 2000.0,
#    'state': 'AR',
#    'state_full': 'Arkansas'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 1,
#    'total': 250.0,
#    'state': 'AZ',
#    'state_full': 'Arizona'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 2,
#    'total': 2950.0,
#    'state': 'CA',
#    'state_full': 'California'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 32,
#    'total': 17631.0,
#    'state': 'FL',
#    'state_full': 'Florida'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 2,
#    'total': 2000.0,
#    'state': 'IL',
#    'state_full': 'Illinois'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 2,
#    'total': 20.0,
#    'state': 'MO',
#    'state_full': 'Missouri'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 2,
#    'total': 1500.0,
#    'state': 'NJ',
#    'state_full': 'New Jersey'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 44,
#    'total': 56233.0,
#    'state': 'NV',
#    'state_full': 'Nevada'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 1,
#    'total': 500.0,
#    'state': 'NY',
#    'state_full': 'New York'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 1,
#    'total': 1000.0,
#    'state': 'OK',
#    'state_full': 'Oklahoma'},
#   {'cycle': 2018,
#    'candidate_id': 'S8NV00149',
#    'count': 12,
#    'total': 270.0,
#    'state': 'WI',
#    'state_full': 'Wisconsin'}]}
