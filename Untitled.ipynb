# %%
import pandas as pd
import requests
from config import api_key
import json

# %%
url="https://api.open.fec.gov/v1/candidates/"
params={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2018,
    "office":"S",
    "api_key":api_key,
    "party":"Dem"
}
data=requests.get(url=url,params=params).json()

# %%
candidate_page_1=pd.DataFrame(data["results"])
candidate_page_1.head()
# Out:
#                            cycles      election_years party district  \
# 0                    [2018, 2020]              [2018]   DEM       00
# 1                          [2018]              [2018]   DEM       00
# 2  [2012, 2014, 2016, 2018, 2020]  [2012, 2018, 2024]   DEM       00
# 3                    [2018, 2020]              [2018]   DEM       00
# 4                    [2018, 2020]        [2018, 2020]   DEM       00
#
#    district_number candidate_id      flags  has_raised_funds  \
# 0                0    S8AZ00122  S8AZ00122              True
# 1                0    S8CT00105  S8CT00105              True
# 2                0    S2WI00219  S2WI00219              True
# 3                0    S8MS00253  S8MS00253              True
# 4                0    S8MS00295  S8MS00295              True
#
#   incumbent_challenge_full office  ...                 name  \
# 0                Open seat      S  ...       ABBOUD, DEEDRA
# 1               Challenger      S  ...  ADAMS, ANN MARIE DR
# 2                Incumbent      S  ...       BALDWIN, TAMMY
# 3                Open seat      S  ...   BARIA, DAVID WAYNE
# 4               Challenger      S  ...        BARTEE, TOBEY
#
#   candidate_inactive office_full candidate_status  active_through  \
# 0              False      Senate                P            2018
# 1              False      Senate                N            2018
# 2              False      Senate                F            2024
# 3              False      Senate                P            2018
# 4              False      Senate                N            2020
#
#   election_districts  state inactive_election_years  \
# 0               [00]     AZ                    None
# 1               [00]     CT                    None
# 2       [00, 00, 00]     WI                    None
# 3               [00]     MS                    None
# 4           [00, 00]     MS                    None
#
#                    load_date  incumbent_challenge
# 0  2019-03-27T16:02:41+00:00                    O
# 1  2018-02-17T09:16:20+00:00                    C
# 2  2019-04-17T21:18:58+00:00                    I
# 3  2019-03-27T16:02:41+00:00                    O
# 4  2020-02-10T21:15:36+00:00                    C
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_2={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2018,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":2
}
page_2=requests.get(url=url,params=params_2).json()

# %%
candidate_page_2=pd.DataFrame(page_2["results"])
candidate_page_2.head()
# Out:
#   office                                     election_years  \
# 0      S                                       [2018, 2020]
# 1      S  [1992, 1994, 1996, 1998, 2000, 2006, 2012, 201...
# 2      S                                             [2018]
# 3      S                           [2010, 2012, 2018, 2024]
# 4      S                                             [2018]
#
#                    load_date last_f2_date  \
# 0  2019-02-25T21:15:37+00:00   2018-11-30
# 1  2019-02-15T22:03:20+00:00   2018-12-06
# 2  2018-02-20T21:22:21+00:00   2017-05-09
# 3  2019-09-06T21:18:42+00:00   2019-09-06
# 4  2018-02-20T21:22:21+00:00   2017-05-15
#
#                                               cycles  \
# 0                                       [2018, 2020]
# 1  [1992, 1994, 1996, 1998, 2000, 2002, 2004, 200...
# 2                                             [2018]
# 3               [2010, 2012, 2014, 2016, 2018, 2020]
# 4                                       [2018, 2020]
#
#                        name  district_number  candidate_inactive  \
# 0             ESPY, MICHAEL                0               False
# 1         FEINSTEIN, DIANNE                0               False
# 2           FISHER, JASON E                0               False
# 3       GILLIBRAND, KIRSTEN                0               False
# 4  HANSEN, LEWIS MICHAEL JR                0               False
#
#   first_file_date      flags  ...        party_full candidate_status  \
# 0      2018-04-05  S8MS00287  ...  DEMOCRATIC PARTY                C
# 1      1991-02-14  S0CA00199  ...  DEMOCRATIC PARTY                F
# 2      2017-05-09  S8AL00357  ...  DEMOCRATIC PARTY                N
# 3      2009-01-28  S0NY00410  ...  DEMOCRATIC PARTY                C
# 4      2017-05-15  S8AL00373  ...  DEMOCRATIC PARTY                N
#
#   active_through  last_file_date party inactive_election_years  \
# 0           2020      2018-11-30   DEM                    None
# 1           2024      2018-12-06   DEM                  [1996]
# 2           2018      2017-05-09   DEM                    None
# 3           2024      2019-09-06   DEM                    None
# 4           2018      2017-05-15   DEM                    None
#
#   has_raised_funds  state incumbent_challenge  \
# 0             True     MS                   C
# 1             True     CA                None
# 2             True     AL                   C
# 3             True     NY                None
# 4             True     AL                   C
#
#                      election_districts
# 0                              [00, 00]
# 1  [00, 00, 00, 00, 00, 00, 00, 00, 00]
# 2                                  [00]
# 3                      [00, 00, 00, 00]
# 4                                  [00]
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_3={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2018,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":3
}
page_3=requests.get(url=url,params=params_3).json()

# %%
candidate_page_3=pd.DataFrame(page_3["results"])
candidate_page_3.head()
# Out:
#   party incumbent_challenge_full  federal_funds_flag  \
# 0   DEM                Open seat               False
# 1   DEM                Open seat               False
# 2   DEM               Challenger               False
# 3   DEM               Challenger               False
# 4   DEM               Challenger               False
#
#                         name  active_through office office_full  \
# 0          RUBEN, DAVID ALAN            2018      S      Senate
# 1  RUSSELL, DALE CHRISTOPHER            2018      S      Senate
# 2               SBAIH, JESSE            2018      S      Senate
# 3         SCOTT, OMERIA LANE            2018      S      Senate
# 4              SEGAL, JEROME            2018      S      Senate
#
#   election_years district incumbent_challenge  ...        party_full  \
# 0   [2012, 2018]       00                   O  ...  DEMOCRATIC PARTY
# 1         [2018]       00                   O  ...  DEMOCRATIC PARTY
# 2         [2018]       00                   C  ...  DEMOCRATIC PARTY
# 3         [2018]       00                   C  ...  DEMOCRATIC PARTY
# 4         [2018]       00                   C  ...  DEMOCRATIC PARTY
#
#   district_number                          cycles election_districts  \
# 0               0  [2012, 2014, 2016, 2018, 2020]           [00, 00]
# 1               0                          [2018]               [00]
# 2               0                    [2018, 2020]               [00]
# 3               0                    [2018, 2020]               [00]
# 4               0                          [2018]               [00]
#
#        flags candidate_status  candidate_inactive                  load_date  \
# 0  S2AZ00265                P               False  2019-03-27T16:02:41+00:00
# 1  S8AZ00148                C               False  2018-04-03T21:07:16+00:00
# 2  S8NV00149                P               False  2019-03-27T16:02:41+00:00
# 3  S8MS00311                P               False  2019-03-27T16:02:41+00:00
# 4  S8MD00252                C               False  2018-04-27T21:22:31+00:00
#
#   inactive_election_years candidate_id
# 0                    None    S2AZ00265
# 1                    None    S8AZ00148
# 2                    None    S8NV00149
# 3                    None    S8MS00311
# 4                    None    S8MD00252
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_4={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2018,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":4
}
page_4=requests.get(url=url,params=params_4).json()

# %%
candidate_page_4=pd.DataFrame(page_4["results"])
candidate_page_4.head()
# Out:
#                    load_date incumbent_challenge last_f2_date  \
# 0  2019-03-27T16:02:41+00:00                   O   2018-01-29
# 1  2018-04-03T21:07:16+00:00                   O   2017-05-26
# 2  2019-03-27T16:02:41+00:00                   C   2017-04-26
# 3  2019-03-27T16:02:41+00:00                   C   2018-05-24
# 4  2018-04-27T21:22:31+00:00                   C   2017-10-18
#
#   election_districts  active_through district last_file_date state  \
# 0           [00, 00]            2018       00     2018-01-29    AZ
# 1               [00]            2018       00     2017-05-26    AZ
# 2               [00]            2018       00     2017-04-26    NV
# 3               [00]            2018       00     2018-06-07    MS
# 4               [00]            2018       00     2017-10-18    MD
#
#   incumbent_challenge_full                       name  ... candidate_inactive  \
# 0                Open seat          RUBEN, DAVID ALAN  ...              False
# 1                Open seat  RUSSELL, DALE CHRISTOPHER  ...              False
# 2               Challenger               SBAIH, JESSE  ...              False
# 3               Challenger         SCOTT, OMERIA LANE  ...              False
# 4               Challenger              SEGAL, JEROME  ...              False
#
#    candidate_status office_full        party_full inactive_election_years  \
# 0                 P      Senate  DEMOCRATIC PARTY                    None
# 1                 C      Senate  DEMOCRATIC PARTY                    None
# 2                 P      Senate  DEMOCRATIC PARTY                    None
# 3                 P      Senate  DEMOCRATIC PARTY                    None
# 4                 C      Senate  DEMOCRATIC PARTY                    None
#
#    election_years first_file_date      flags candidate_id has_raised_funds
# 0    [2012, 2018]      2012-01-09  S2AZ00265    S2AZ00265             True
# 1          [2018]      2017-05-26  S8AZ00148    S8AZ00148             True
# 2          [2018]      2017-04-26  S8NV00149    S8NV00149             True
# 3          [2018]      2018-05-24  S8MS00311    S8MS00311             True
# 4          [2018]      2017-10-18  S8MD00252    S8MD00252             True
#
# [5 rows x 25 columns]

# %%
url="https://api.open.fec.gov/v1/candidates/"
params_5={
    "has_raised_funds":True,
    "sort_null_only":False,
    "election_year":2018,
    "office":"S",
    "api_key":api_key,
    "party":"Dem",
    "page":5
}
page_5=requests.get(url=url,params=params_5).json()

# %%
candidate_page_5=pd.DataFrame(page_5["results"])
candidate_page_5.head()
# Out:
#                    load_date incumbent_challenge last_f2_date  \
# 0  2019-03-27T16:02:41+00:00                   O   2017-07-18
#
#   election_districts  active_through district last_file_date state  \
# 0               [00]            2018       00     2017-07-18    UT
#
#   incumbent_challenge_full           name  ... candidate_inactive  \
# 0                Open seat  WILSON, JENNY  ...              False
#
#    candidate_status office_full        party_full inactive_election_years  \
# 0                 P      Senate  DEMOCRATIC PARTY                    None
#
#    election_years first_file_date      flags candidate_id has_raised_funds
# 0          [2018]      2017-07-18  S8UT00143    S8UT00143             True
#
# [1 rows x 25 columns]

# %%
candidate_page_1
# Out:
#                                                cycles  \
# 0                                        [2018, 2020]
# 1                                              [2018]
# 2                      [2012, 2014, 2016, 2018, 2020]
# 3                                        [2018, 2020]
# 4                                        [2018, 2020]
# 5                                              [2018]
# 6                                        [2018, 2020]
# 7                                              [2018]
# 8                                        [2018, 2020]
# 9    [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020]
# 10  [2000, 2002, 2004, 2006, 2008, 2010, 2012, 201...
# 11  [2000, 2006, 2008, 2010, 2012, 2014, 2016, 201...
# 12  [2000, 2002, 2004, 2006, 2008, 2010, 2012, 201...
# 13   [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020]
# 14                                             [2018]
# 15  [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...
# 16                                       [2018, 2020]
# 17                     [2012, 2014, 2016, 2018, 2020]
# 18                                 [2016, 2018, 2020]
# 19                                       [2018, 2020]
#
#                                 election_years party district  \
# 0                                       [2018]   DEM       00
# 1                                       [2018]   DEM       00
# 2                           [2012, 2018, 2024]   DEM       00
# 3                                       [2018]   DEM       00
# 4                                 [2018, 2020]   DEM       00
# 5                                       [2018]   DEM       00
# 6                                 [2018, 2020]   DEM       00
# 7                                       [2018]   DEM       00
# 8                                       [2018]   DEM       00
# 9                     [2006, 2012, 2018, 2024]   DEM       00
# 10              [2000, 2006, 2012, 2018, 2024]   DEM       00
# 11              [2000, 2006, 2012, 2018, 2024]   DEM       00
# 12              [2000, 2006, 2012, 2018, 2024]   DEM       00
# 13                    [2006, 2012, 2018, 2024]   DEM       00
# 14                                      [2018]   DEM       00
# 15  [2002, 2006, 2008, 2012, 2014, 2018, 2020]   DEM       00
# 16                                      [2018]   DEM       00
# 17                                [2012, 2018]   DEM       00
# 18                          [2016, 2018, 2022]   DEM       00
# 19                                      [2018]   DEM       00
#
#     district_number candidate_id      flags  has_raised_funds  \
# 0                 0    S8AZ00122  S8AZ00122              True
# 1                 0    S8CT00105  S8CT00105              True
# 2                 0    S2WI00219  S2WI00219              True
# 3                 0    S8MS00253  S8MS00253              True
# 4                 0    S8MS00295  S8MS00295              True
# 5                 0    S8AZ00171  S8AZ00171              True
# 6                 0    S8MS00220  S8MS00220              True
# 7                 0    S8AL00407  S8AL00407              True
# 8                 0    S8TN00386  S8TN00386              True
# 9                 0    S6OH00163  S6OH00163              True
# 10                0    S8WA00194  S8WA00194              True
# 11                0    S6MD03177  S6MD03177              True
# 12                0    S8DE00079  S8DE00079              True
# 13                0    S6PA00217  S6PA00217              True
# 14                0    S8NV00131  S8NV00131              True
# 15                0    S2TN00082  S2TN00082              True
# 16                0    S8CA00408  S8CA00408              True
# 17                0    S2IN00091  S2IN00091              True
# 18                0    S6IL00292  S6IL00292              True
# 19                0    S8MO00186  S8MO00186              True
#
#    incumbent_challenge_full office  ...                            name  \
# 0                 Open seat      S  ...                  ABBOUD, DEEDRA
# 1                Challenger      S  ...             ADAMS, ANN MARIE DR
# 2                 Incumbent      S  ...                  BALDWIN, TAMMY
# 3                 Open seat      S  ...              BARIA, DAVID WAYNE
# 4                Challenger      S  ...                   BARTEE, TOBEY
# 5                 Open seat      S  ...       BISHOP, ROBERT BOB GRIMES
# 6                Challenger      S  ...               BOHREN, JENSEN MR
# 7                Challenger      S  ...  BOYD JR, WILLIE "WILL"  EUGENE
# 8                 Open seat      S  ...                BREDESEN, PHILIP
# 9                      None      S  ...                  BROWN, SHERROD
# 10                     None      S  ...                 CANTWELL, MARIA
# 11                Incumbent      S  ...              CARDIN, BENJAMIN L
# 12                     None      S  ...               CARPER, THOMAS R.
# 13                     None      S  ...            CASEY, ROBERT P. JR.
# 14               Challenger      S  ...           CRADDOCK, JAY GREGORY
# 15                Open seat      S  ...                DAVIS, GARY GENE
# 16               Challenger      S  ...                  DE LEON, KEVIN
# 17                Incumbent      S  ...              DONNELLY, JOSEPH S
# 18               Challenger      S  ...              DUCKWORTH, L TAMMY
# 19               Challenger      S  ...                  EARL, ANGELICA
#
#    candidate_inactive office_full candidate_status  active_through  \
# 0               False      Senate                P            2018
# 1               False      Senate                N            2018
# 2               False      Senate                F            2024
# 3               False      Senate                P            2018
# 4               False      Senate                N            2020
# 5               False      Senate                C            2018
# 6               False      Senate                N            2020
# 7               False      Senate                N            2018
# 8               False      Senate                P            2018
# 9               False      Senate                F            2024
# 10              False      Senate                F            2024
# 11              False      Senate                C            2024
# 12              False      Senate                F            2024
# 13              False      Senate                F            2024
# 14              False      Senate                C            2018
# 15              False      Senate                N            2020
# 16              False      Senate                P            2018
# 17              False      Senate                P            2018
# 18              False      Senate                F            2022
# 19              False      Senate                N            2018
#
#               election_districts  state inactive_election_years  \
# 0                           [00]     AZ                    None
# 1                           [00]     CT                    None
# 2                   [00, 00, 00]     WI                    None
# 3                           [00]     MS                    None
# 4                       [00, 00]     MS                    None
# 5                           [00]     AZ                    None
# 6                       [00, 00]     MS                    None
# 7                           [00]     AL                    None
# 8                           [00]     TN                    None
# 9               [00, 00, 00, 00]     OH                    None
# 10          [00, 00, 00, 00, 00]     WA                    None
# 11          [00, 00, 00, 00, 00]     MD                    None
# 12          [00, 00, 00, 00, 00]     DE                    None
# 13              [00, 00, 00, 00]     PA                    None
# 14                          [00]     NV                    None
# 15  [00, 00, 00, 00, 00, 00, 00]     TN                    None
# 16                          [00]     CA                    None
# 17                      [00, 00]     IN                    None
# 18                  [00, 00, 00]     IL                    None
# 19                          [00]     MO                    None
#
#                     load_date  incumbent_challenge
# 0   2019-03-27T16:02:41+00:00                    O
# 1   2018-02-17T09:16:20+00:00                    C
# 2   2019-04-17T21:18:58+00:00                    I
# 3   2019-03-27T16:02:41+00:00                    O
# 4   2020-02-10T21:15:36+00:00                    C
# 5   2018-04-03T21:07:16+00:00                    O
# 6   2019-06-14T21:08:39+00:00                    C
# 7   2018-02-20T21:22:21+00:00                    C
# 8   2019-03-27T16:02:41+00:00                    O
# 9   2019-02-25T21:15:37+00:00                 None
# 10  2019-04-01T21:06:00+00:00                 None
# 11  2019-02-25T21:15:37+00:00                    I
# 12  2019-02-15T22:03:20+00:00                 None
# 13  2019-06-26T21:24:11+00:00                 None
# 14  2018-02-17T09:16:20+00:00                    C
# 15  2020-08-21T01:04:24+00:00                    O
# 16  2019-03-27T16:02:41+00:00                    C
# 17  2019-03-27T16:02:41+00:00                    I
# 18  2019-08-01T21:25:13+00:00                    C
# 19  2018-02-17T09:16:20+00:00                    C
#
# [20 rows x 25 columns]

# %%
dfs_to_concat = [candidate_page_1, candidate_page_2, candidate_page_3, candidate_page_4, candidate_page_5]

# %%
dem_candidates=pd.concat(dfs_to_concat)

# %%
dem_candidates=dem_candidates[["name", "candidate_id", "state", "party", "incumbent_challenge_full", "office_full", "cycles", "election_years", "party", "candidate_status"]]
# Out:
#                                               cycles  \
# 0                                       [2018, 2020]
# 1                                             [2018]
# 2                     [2012, 2014, 2016, 2018, 2020]
# 3                                       [2018, 2020]
# 4                                       [2018, 2020]
# ..                                               ...
# 16                                      [2018, 2020]
# 17                                      [2018, 2020]
# 18                    [2012, 2014, 2016, 2018, 2020]
# 19  [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020]
# 0                                       [2018, 2020]
#
#               election_years party district  district_number candidate_id  \
# 0                     [2018]   DEM       00                0    S8AZ00122
# 1                     [2018]   DEM       00                0    S8CT00105
# 2         [2012, 2018, 2024]   DEM       00                0    S2WI00219
# 3                     [2018]   DEM       00                0    S8MS00253
# 4               [2018, 2020]   DEM       00                0    S8MS00295
# ..                       ...   ...      ...              ...          ...
# 16                    [2018]   DEM       00                0    S8WY00189
# 17                    [2018]   DEM       00                0    S8UT00150
# 18        [2012, 2018, 2024]   DEM       00                0    S2MA00170
# 19  [2006, 2012, 2018, 2024]   DEM       00                0    S6RI00221
# 0                     [2018]   DEM       00                0    S8UT00143
#
#         flags  has_raised_funds incumbent_challenge_full office  ...  \
# 0   S8AZ00122              True                Open seat      S  ...
# 1   S8CT00105              True               Challenger      S  ...
# 2   S2WI00219              True                Incumbent      S  ...
# 3   S8MS00253              True                Open seat      S  ...
# 4   S8MS00295              True               Challenger      S  ...
# ..        ...               ...                      ...    ...  ...
# 16  S8WY00189              True               Challenger      S  ...
# 17  S8UT00150              True                Open seat      S  ...
# 18  S2MA00170              True                Incumbent      S  ...
# 19  S6RI00221              True                     None      S  ...
# 0   S8UT00143              True                Open seat      S  ...
#
#                    name candidate_inactive office_full candidate_status  \
# 0        ABBOUD, DEEDRA              False      Senate                P
# 1   ADAMS, ANN MARIE DR              False      Senate                N
# 2        BALDWIN, TAMMY              False      Senate                F
# 3    BARIA, DAVID WAYNE              False      Senate                P
# 4         BARTEE, TOBEY              False      Senate                N
# ..                  ...                ...         ...              ...
# 16        TRAUNER, GARY              False      Senate                P
# 17  VICE, MITCHELL KENT              False      Senate                N
# 18    WARREN, ELIZABETH              False      Senate                F
# 19  WHITEHOUSE, SHELDON              False      Senate                F
# 0         WILSON, JENNY              False      Senate                P
#
#     active_through election_districts  state inactive_election_years  \
# 0             2018               [00]     AZ                    None
# 1             2018               [00]     CT                    None
# 2             2024       [00, 00, 00]     WI                    None
# 3             2018               [00]     MS                    None
# 4             2020           [00, 00]     MS                    None
# ..             ...                ...    ...                     ...
# 16            2018               [00]     WY                    None
# 17            2018               [00]     UT                    None
# 18            2024       [00, 00, 00]     MA                    None
# 19            2024   [00, 00, 00, 00]     RI                    None
# 0             2018               [00]     UT                    None
#
#                     load_date  incumbent_challenge
# 0   2019-03-27T16:02:41+00:00                    O
# 1   2018-02-17T09:16:20+00:00                    C
# 2   2019-04-17T21:18:58+00:00                    I
# 3   2019-03-27T16:02:41+00:00                    O
# 4   2020-02-10T21:15:36+00:00                    C
# ..                        ...                  ...
# 16  2019-03-27T16:02:41+00:00                    C
# 17  2018-04-03T21:07:16+00:00                    O
# 18  2020-03-23T21:12:04+00:00                    I
# 19  2019-02-25T21:15:37+00:00                 None
# 0   2019-03-27T16:02:41+00:00                    O
#
# [81 rows x 25 columns]
